# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pymodulon.core import IcaData
from pymodulon import example_data
from pymodulon.io import save_to_json, load_json_model
from pymodulon.enrichment import *

# %% [markdown]
# ### Read in all ica object files

# %%
tpm = pd.read_csv('logTPM_norm_file.csv',index_col='gene_id')
tpm.index = tpm.index.where(~tpm.index.duplicated(), tpm.index + '_1')

updated_gene_index = []
for index in tpm.index:
    updated_gene_index.append(index.replace('gene-',''))

tpm.index = updated_gene_index

gene_table = pd.read_csv('yarrowia_NCBI_table.csv',index_col='Locus tag')
sample_table = pd.read_table('final_metadata_file.tsv', index_col='Unnamed: 0')

# %% [markdown]
# ### Add in tables to ICA object

# %%
A = pd.read_csv('A.csv',index_col='Unnamed: 0')
M = pd.read_csv('S.csv',index_col='gene_id')
TRN = pd.read_csv('yarrowiaTRN.csv',index_col = 'Unnamed: 0')

# Remove duplicate gene names
M.index = M.index.where(~M.index.duplicated(), M.index + '_1')
gene_table.index = gene_table.index.where(~gene_table.index.duplicated(), gene_table.index + '_1')

updated_gene_index = []
for index in M.index:
    updated_gene_index.append(index.replace('gene-',''))

M.index = updated_gene_index


# Filter out ribosomal and mitochondrial RNA (not annotated in NCBI gene table?)


available_M_genes = []

for i in M.index:
    if(i in gene_table.index.tolist()):
        available_M_genes.append(i)

M = M.loc[available_M_genes]
tpm = tpm.loc[available_M_genes]


# Create ICA object 
ica_data = IcaData(M,A)
ica_data.X = tpm
ica_data.gene_table = gene_table
ica_data.sample_table = sample_table
ica_data.trn = TRN

# %% [markdown]
# ### Apply M matrix thresholds to obtain filtered imodulons

# %%
test_data = IcaData(ica_data.M,
                    ica_data.A,
                    trn=ica_data.trn,
                    threshold_method='dagostino')
# Out:
# WARNING:root:Using the default dagostino_cutoff of 550. This may not be optimal for your dataset. Use ica_data.reoptimize_thresholds() to find the optimal threshold.

# %% [markdown]
# ### Enrich imodulons

# %%
imodulon_genes = list(test_data.view_imodulon(1).index)
enriched_regulons = compute_trn_enrichment(imodulon_genes,M.index,TRN)

imodulon_table = enriched_regulons
imodulon_name = []
j = 0

for i in range(2,M.shape[1]):
    imodulon_genes = list(test_data.view_imodulon(i).index)
    enriched_regulons = compute_trn_enrichment(imodulon_genes,M.index,TRN)
    
    if(enriched_regulons.shape[0]):
        imodulon_table = pd.concat([imodulon_table,enriched_regulons.iloc[0,:]],axis=1)
        imodulon_name.append(enriched_regulons.iloc[0].name)
        
    else:
        imodulon_table = pd.concat([imodulon_table,enriched_regulons],axis=1)
        imodulon_name.append('Uncharacterized_'+str(j))
        j = j+1

ica_data.compute_trn_enrichment(save=True)
ica_data.imodulon_table
# Out:
# /usr/local/lib/python3.8/dist-packages/pymodulon/core.py:610: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   keep_cols = self.imodulon_table.loc[
#    regulator        pvalue        qvalue  precision    recall   f1score    TP  \
# 0       HAP4  1.320425e-08  8.841645e-07   0.036750  0.351852  0.066550  19.0
# 1        NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 2       GCN4  5.959733e-13  5.542552e-11   0.289855  0.083565  0.129730  60.0
# 3        NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 4        NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 5        NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 6        NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 7        NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 8        NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 9        NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 10       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 11       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 12       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 13      IFH1  3.442528e-84  3.476953e-82   0.236422  0.813187  0.366337  74.0
# 14       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 15       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 16       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 17       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 18      ADR1  1.236264e-08  8.035717e-07   0.148148  0.145455  0.146789   8.0
# 19       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 20      MBP1  1.652559e-10  1.388150e-08   0.062284  0.281250  0.101983  18.0
# 21       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 22       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 23       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 24       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 25       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 26       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 27       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 28       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 29       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 30       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 31       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 32       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 33       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 34       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 35       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 36      HSF1  1.835481e-12  1.450030e-10   0.136054  0.165289  0.149254  20.0
# 37       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 38       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 39       NaN           NaN           NaN        NaN       NaN       NaN   NaN
# 40       NaN           NaN           NaN        NaN       NaN       NaN   NaN
#
#     regulon_size  imodulon_size  n_regs
# 0           54.0          517.0     1.0
# 1            NaN            NaN     NaN
# 2          718.0          207.0     1.0
# 3            NaN            NaN     NaN
# 4            NaN            NaN     NaN
# 5            NaN            NaN     NaN
# 6            NaN            NaN     NaN
# 7            NaN            NaN     NaN
# 8            NaN            NaN     NaN
# 9            NaN            NaN     NaN
# 10           NaN            NaN     NaN
# 11           NaN            NaN     NaN
# 12           NaN            NaN     NaN
# 13          91.0          313.0     1.0
# 14           NaN            NaN     NaN
# 15           NaN            NaN     NaN
# 16           NaN            NaN     NaN
# 17           NaN            NaN     NaN
# 18          55.0           54.0     1.0
# 19           NaN            NaN     NaN
# 20          64.0          289.0     1.0
# 21           NaN            NaN     NaN
# 22           NaN            NaN     NaN
# 23           NaN            NaN     NaN
# 24           NaN            NaN     NaN
# 25           NaN            NaN     NaN
# 26           NaN            NaN     NaN
# 27           NaN            NaN     NaN
# 28           NaN            NaN     NaN
# 29           NaN            NaN     NaN
# 30           NaN            NaN     NaN
# 31           NaN            NaN     NaN
# 32           NaN            NaN     NaN
# 33           NaN            NaN     NaN
# 34           NaN            NaN     NaN
# 35           NaN            NaN     NaN
# 36         121.0          147.0     1.0
# 37           NaN            NaN     NaN
# 38           NaN            NaN     NaN
# 39           NaN            NaN     NaN
# 40           NaN            NaN     NaN

# %% [markdown]
# ### Add regulator names to imodulons

# %%
# imodulon_names = []

# j = 1
# for regulator in ica_data.imodulon_table['regulator']:
#     if(pd.isna(regulator)):
#         imodulon_names.append('Uncharacterized_'+str(j))
#         j = j+1
#     else:
#         imodulon_names.append(regulator)
        
# ica_data.imodulon_table.index = imodulon_names
# ica_data.imodulon_table
# Out:
#                    regulator        pvalue        qvalue  precision    recall  \
# HAP4                    HAP4  1.320425e-08  8.841645e-07   0.036750  0.351852
# Uncharacterized_1        NaN           NaN           NaN        NaN       NaN
# GCN4                    GCN4  5.959733e-13  5.542552e-11   0.289855  0.083565
# Uncharacterized_2        NaN           NaN           NaN        NaN       NaN
# Uncharacterized_3        NaN           NaN           NaN        NaN       NaN
# Uncharacterized_4        NaN           NaN           NaN        NaN       NaN
# Uncharacterized_5        NaN           NaN           NaN        NaN       NaN
# Uncharacterized_6        NaN           NaN           NaN        NaN       NaN
# Uncharacterized_7        NaN           NaN           NaN        NaN       NaN
# Uncharacterized_8        NaN           NaN           NaN        NaN       NaN
# Uncharacterized_9        NaN           NaN           NaN        NaN       NaN
# Uncharacterized_10       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_11       NaN           NaN           NaN        NaN       NaN
# IFH1                    IFH1  3.442528e-84  3.476953e-82   0.236422  0.813187
# Uncharacterized_12       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_13       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_14       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_15       NaN           NaN           NaN        NaN       NaN
# ADR1                    ADR1  1.236264e-08  8.035717e-07   0.148148  0.145455
# Uncharacterized_16       NaN           NaN           NaN        NaN       NaN
# MBP1                    MBP1  1.652559e-10  1.388150e-08   0.062284  0.281250
# Uncharacterized_17       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_18       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_19       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_20       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_21       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_22       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_23       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_24       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_25       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_26       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_27       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_28       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_29       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_30       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_31       NaN           NaN           NaN        NaN       NaN
# HSF1                    HSF1  1.835481e-12  1.450030e-10   0.136054  0.165289
# Uncharacterized_32       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_33       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_34       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_35       NaN           NaN           NaN        NaN       NaN
#
#                      f1score    TP  regulon_size  imodulon_size  n_regs
# HAP4                0.066550  19.0          54.0          517.0     1.0
# Uncharacterized_1        NaN   NaN           NaN            NaN     NaN
# GCN4                0.129730  60.0         718.0          207.0     1.0
# Uncharacterized_2        NaN   NaN           NaN            NaN     NaN
# Uncharacterized_3        NaN   NaN           NaN            NaN     NaN
# Uncharacterized_4        NaN   NaN           NaN            NaN     NaN
# Uncharacterized_5        NaN   NaN           NaN            NaN     NaN
# Uncharacterized_6        NaN   NaN           NaN            NaN     NaN
# Uncharacterized_7        NaN   NaN           NaN            NaN     NaN
# Uncharacterized_8        NaN   NaN           NaN            NaN     NaN
# Uncharacterized_9        NaN   NaN           NaN            NaN     NaN
# Uncharacterized_10       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_11       NaN   NaN           NaN            NaN     NaN
# IFH1                0.366337  74.0          91.0          313.0     1.0
# Uncharacterized_12       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_13       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_14       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_15       NaN   NaN           NaN            NaN     NaN
# ADR1                0.146789   8.0          55.0           54.0     1.0
# Uncharacterized_16       NaN   NaN           NaN            NaN     NaN
# MBP1                0.101983  18.0          64.0          289.0     1.0
# Uncharacterized_17       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_18       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_19       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_20       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_21       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_22       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_23       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_24       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_25       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_26       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_27       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_28       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_29       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_30       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_31       NaN   NaN           NaN            NaN     NaN
# HSF1                0.149254  20.0         121.0          147.0     1.0
# Uncharacterized_32       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_33       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_34       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_35       NaN   NaN           NaN            NaN     NaN

# %%
from pymodulon.plotting import *
metadata_boxplot(ica_data,1,n_boxes=5,use_cols=['conditions'],
                 show_points=False);
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/tree/_classes.py:366: FutureWarning: Criterion 'mae' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='absolute_error'` which is equivalent.
#   warnings.warn(

# %%
ica_data.imodulon_table
# Out:
#                    regulator        pvalue        qvalue  precision    recall  \
# HAP4                    HAP4  1.320425e-08  8.841645e-07   0.036750  0.351852
# Uncharacterized_1        NaN           NaN           NaN        NaN       NaN
# GCN4                    GCN4  5.959733e-13  5.542552e-11   0.289855  0.083565
# Uncharacterized_2        NaN           NaN           NaN        NaN       NaN
# Uncharacterized_3        NaN           NaN           NaN        NaN       NaN
# Uncharacterized_4        NaN           NaN           NaN        NaN       NaN
# Uncharacterized_5        NaN           NaN           NaN        NaN       NaN
# Uncharacterized_6        NaN           NaN           NaN        NaN       NaN
# Uncharacterized_7        NaN           NaN           NaN        NaN       NaN
# Uncharacterized_8        NaN           NaN           NaN        NaN       NaN
# Uncharacterized_9        NaN           NaN           NaN        NaN       NaN
# Uncharacterized_10       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_11       NaN           NaN           NaN        NaN       NaN
# IFH1                    IFH1  3.442528e-84  3.476953e-82   0.236422  0.813187
# Uncharacterized_12       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_13       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_14       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_15       NaN           NaN           NaN        NaN       NaN
# ADR1                    ADR1  1.236264e-08  8.035717e-07   0.148148  0.145455
# Uncharacterized_16       NaN           NaN           NaN        NaN       NaN
# MBP1                    MBP1  1.652559e-10  1.388150e-08   0.062284  0.281250
# Uncharacterized_17       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_18       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_19       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_20       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_21       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_22       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_23       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_24       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_25       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_26       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_27       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_28       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_29       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_30       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_31       NaN           NaN           NaN        NaN       NaN
# HSF1                    HSF1  1.835481e-12  1.450030e-10   0.136054  0.165289
# Uncharacterized_32       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_33       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_34       NaN           NaN           NaN        NaN       NaN
# Uncharacterized_35       NaN           NaN           NaN        NaN       NaN
#
#                      f1score    TP  regulon_size  imodulon_size  n_regs
# HAP4                0.066550  19.0          54.0          517.0     1.0
# Uncharacterized_1        NaN   NaN           NaN            NaN     NaN
# GCN4                0.129730  60.0         718.0          207.0     1.0
# Uncharacterized_2        NaN   NaN           NaN            NaN     NaN
# Uncharacterized_3        NaN   NaN           NaN            NaN     NaN
# Uncharacterized_4        NaN   NaN           NaN            NaN     NaN
# Uncharacterized_5        NaN   NaN           NaN            NaN     NaN
# Uncharacterized_6        NaN   NaN           NaN            NaN     NaN
# Uncharacterized_7        NaN   NaN           NaN            NaN     NaN
# Uncharacterized_8        NaN   NaN           NaN            NaN     NaN
# Uncharacterized_9        NaN   NaN           NaN            NaN     NaN
# Uncharacterized_10       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_11       NaN   NaN           NaN            NaN     NaN
# IFH1                0.366337  74.0          91.0          313.0     1.0
# Uncharacterized_12       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_13       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_14       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_15       NaN   NaN           NaN            NaN     NaN
# ADR1                0.146789   8.0          55.0           54.0     1.0
# Uncharacterized_16       NaN   NaN           NaN            NaN     NaN
# MBP1                0.101983  18.0          64.0          289.0     1.0
# Uncharacterized_17       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_18       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_19       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_20       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_21       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_22       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_23       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_24       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_25       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_26       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_27       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_28       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_29       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_30       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_31       NaN   NaN           NaN            NaN     NaN
# HSF1                0.149254  20.0         121.0          147.0     1.0
# Uncharacterized_32       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_33       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_34       NaN   NaN           NaN            NaN     NaN
# Uncharacterized_35       NaN   NaN           NaN            NaN     NaN
